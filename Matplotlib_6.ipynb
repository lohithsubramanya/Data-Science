# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
cities = pd.read_csv('california_cities.csv')

# %%
cities.head()
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
# ...

# %%
lat,lon = cities['latd'], cities['longd']

# %%
population,area = cities['population_total'],cities['area_total_km2']

# %%
plt.scatter(lat, lon, c = np.log10(population), cmap = 'viridis', s = area, alpha = 0.5)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label = 'log10(population)')

# %%
x = np.linspace(0,10,1000)
I = np.sin(x) * np.cos(x[:,np.newaxis])  ### np.newaxis converts the 1D data to a 2D data and presents it in an organised way

# %%
x.shape
# Out:
# (1000,)

# %%
np.cos(x[:,np.newaxis]).shape  ## shape
# Out:
# (1000, 1)

# %%
x[:,np.newaxis].ndim   ### checks dimensions
# Out:
# 2

# %%
plt.imshow(I)

# %%
plt.imshow(I)
plt.colorbar()

# %%
plt.imshow(I)
plt.colorbar()
I[0][6]
# Out:
# 0.06002395835563764

# %%
plt.imshow(I, cmap='gray')

# %%
# load images of the digits 0 through 5 and visualize several of them
from sklearn.datasets import load_digits
digits = load_digits(n_class=6)

# %%
for i,j in enumerate([11,22,33,44]):
    print(i,j)
# Out:
# 0 11
# 1 22
# 2 33
# 3 44

# %%
fig, ax = plt.subplots(4,4, figsize=(6,6))
# ax is a 4 X 4 storage, ax.flat maps it into 16 size of 1 d array
for i,axi in enumerate(ax.flat):
    axi.imshow(digits.images[i], cmap='inferno')
    axi.set(xticks=[], yticks=[]) # disable axis marking

# %%
digits.images[15]
# Out:
# array([[  0.,   1.,   8.,  12.,  15.,  14.,   4.,   0.],
#        [  0.,   3.,  11.,   8.,   8.,  12.,  12.,   0.],
#        [  0.,   0.,   0.,   0.,   2.,  13.,   7.,   0.],
#        [  0.,   0.,   0.,   2.,  15.,  12.,   1.,   0.],
#        [  0.,   0.,   0.,   0.,  13.,   5.,   0.,   0.],
#        [  0.,   0.,   0.,   0.,   9.,  13.,   0.,   0.],
#        [  0.,   0.,   7.,   8.,  14.,  15.,   0.,   0.],
#        [  0.,   0.,  14.,  15.,  11.,   2.,   0.,   0.]])

# %%
digits.images[1]
# Out:
# array([[  0.,   0.,   0.,  12.,  13.,   5.,   0.,   0.],
#        [  0.,   0.,   0.,  11.,  16.,   9.,   0.,   0.],
#        [  0.,   0.,   3.,  15.,  16.,   6.,   0.,   0.],
#        [  0.,   7.,  15.,  16.,  16.,   2.,   0.,   0.],
#        [  0.,   0.,   1.,  16.,  16.,   3.,   0.,   0.],
#        [  0.,   0.,   1.,  16.,  16.,   6.,   0.,   0.],
#        [  0.,   0.,   1.,  16.,  16.,   6.,   0.,   0.],
#        [  0.,   0.,   0.,  11.,  16.,  10.,   0.,   0.]])

# %%
ax1 = plt.axes()

# %%
ax1 = plt.axes()
ax2 = plt.axes([0.65, 0.65, 0.5, 0.5]) #The 4 arguments are distance from left, bottom, width, height

# %%
fig,ax = plt.subplots(2,3)
for i in range(2):
    for j in range(3):
        ax[i,j].text(0.0,0.5, str((i,j)))

# %%
fig,ax = plt.subplots(2,3)
for i in range(2):
    for j in range(3):
        ax[i,j].text(0.0,0.5, str((i,j)))
        #a[i,j]
        
#fig
